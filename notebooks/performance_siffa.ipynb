# %%
# %load_ext autoreload
# %autoreload 2
from athletics_performance import Performance
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 get_ipython().run_line_magic('load_ext', 'autoreload')
#       2 get_ipython().run_line_magic('autoreload', '2')
# ----> 3 from athletics_performance import Performance
#
# ModuleNotFoundError: No module named 'athletics_performance'

# %%
perf = Performance()
p1 = Performance("1:23.45")
p1.convert()
# Out:
# 83.45

# %%
import pandas as pd

# %%
import sys
print(sys.executable)
# Out:
# /home/10017624/P_PROGRAMMES/ACL/202603_GIT_ATHLETICS_PERFORMANCE/.venv/bin/python
