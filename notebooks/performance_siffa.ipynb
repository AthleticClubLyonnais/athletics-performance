# %%
from athletics_performance import Performance

# %%
perf = Performance()
p1 = Performance("1:23.45")
p1.convert()
# Out:
# 83.45

# %%
import pandas as pd

# %%
import sys
print(sys.executable)
# Out:
# /home/10017624/P_PROGRAMMES/ACL/202603_GIT_ATHLETICS_PERFORMANCE/.venv/bin/python
